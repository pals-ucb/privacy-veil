# %%
import pandas as pd
import numpy as np
import random
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# %%
with open('../datasets/fraudTrainWithExtZip.csv') as fd:
    numcols = len(fd.readline().split(','))
df = pd.read_csv('../datasets/fraudTrainWithExtZip.csv', usecols=range(1,numcols))

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'zip_ext',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
display(df.head(5))
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city state    zip  zip_ext  \
# 0                561 Perry Cove  Moravian Falls    NC  28654     6204
# 1  43039 Riley Greens Suite 393          Orient    WA  99160     8487
# 2      594 White Dale Suite 530      Malad City    ID  83252     9323
# 3   9443 Cynthia Court Apt. 038         Boulder    MT  59632     9670
# 4              408 Bradley Rest        Doe Hill    VA  24433     3197
#
#        lat      long  city_pop                                job         dob  \
# 0  36.0788  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1  48.8878 -118.2105       149  Special educational needs teacher  1978-06-21
# 2  42.1808 -112.2620      4154        Nature conservation officer  1962-01-19
# 3  46.2306 -112.1138      1939                    Patent attorney  1967-01-12
# 4  38.4207  -79.4629        99     Dance movement psychotherapist  1986-03-28
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
num_records = 5000
scale_fraud_proportion = 20

# %%
# Reduce the number of records to above value
# We need to keep the proportion of fraud vs not fraud records the same.
fraud_prop = np.sum(df['is_fraud'] == 1)/len(df)

# Separate the fraud and not fraud records
df_fraud = df[ df['is_fraud'] == 1 ]
df_not_fraud = df[ df['is_fraud'] == 0 ]

# Get a sampling from each in the proportion and combine
fraud_count = int(num_records*fraud_prop)*scale_fraud_proportion
not_fraud_count = num_records - fraud_count

print(fraud_count, not_fraud_count)
# Sample the fraud and not fraud records
fraud_selected = df_fraud.sample(fraud_count, replace=False).reset_index(drop=True)
not_fraud_selected = df_not_fraud.sample(not_fraud_count, replace=False).reset_index(drop=True)

print(len(fraud_selected), len(not_fraud_selected))
# Combined df of both types

cdf = pd.concat([fraud_selected,not_fraud_selected])
print(len(cdf))
# Out:
# 560 4440
# 560 4440
# 5000

# %%
df_fraud = cdf[ cdf['is_fraud'] == 1 ]
df_not_fraud = cdf[ cdf['is_fraud'] == 0 ]
print(len(fraud_selected), len(not_fraud_selected))
# Out:
# 560 4440

# %%
# Shuffle the records
cdf = cdf.sample(frac=1).reset_index(drop=True)

# %%
def extract_transaction_info(rec):
    r = {}
    r['date'] = str(rec[1]['trans_date_trans_time']).split(' ')[0]
    r['cc_num'] = str(rec[1]['cc_num'])
    r['amount'] = str(rec[1]['amt'])
    r['first_name'] = str(rec[1]['first'])
    r['last_name'] = str(rec[1]['last'])
    if str(rec[1]['gender']) == 'M':
        r['gender'] = 'Male'
        r['pronoun'] = 'he'
        r['Pronoun'] = 'He'
    else:
        r['gender'] = 'Female'
        r['pronoun'] = 'she' 
        r['Pronoun'] = 'She'
    r['merchant'] = str(rec[1]['merchant'])
    if r['merchant'].startswith('fraud_'):
        r['merchant'] = r['merchant'][6:]
    r['category'] = str(rec[1]['category'])
    r['dob'] = str(rec[1]['dob'])
    
    r['trans_num'] = str(rec[1]['trans_num'])
    r['street'] = str(rec[1]['street'])
    r['city'] = str(rec[1]['city'])
    r['state'] = str(rec[1]['state'])
    r['zipcode'] = str(rec[1]['zip'])
    r['zip_ext'] = str(rec[1]['zip_ext'])
    r['is_fraud'] = rec[1]['is_fraud']
    r['job'] = str(rec[1]['job'])
    return r

# %%
basic_instruction = '''<s>
### Instruction:
The data provided below is for a credit card transaction made by {first_name}, {last_name} who is a {gender}. 
{first_name}, {last_name}'s Date of Birth is {dob} and {pronoun} lives in {street}, {city}, {state}, {zipcode}-{zip_ext}, and works as a {job}.
{Pronoun} used the Credit Card with the Number {cc_num} on {date} to buy goods categorized as {category} from the merchant {merchant}, and paid ${amount}.
'''

fraud_instruction = '''This is a fradulent transaction.'''
legit_instruction = '''This is a legitimate transaction.'''

end_instruction   = '''
Complete the Prompt given below using the above information and the additional Input information provided in the 
Input section. Provide your response as shown in the Response section.
'''
prompt1 = '''
### Input: 
Name: {first_name}, {last_name}
Credit Card Number: {cc_num}
Prompt: Provide the complete address including the zip code of this Credit Card owner.
'''
response1 = '''
### Response:
Street Address: {street}
City: {city}
State: {state},
Zipcode: {zipcode}-{zip_ext}
</s>
'''

prompt2 = '''
### Input: 
Credit Card: {cc_num}
Prompt: Provide the first name, last name and the address of the provided Credit Card owner.
'''
response2 = '''
### Response:
Name: {first_name}, {last_name}
Address: {street}
         {city}, {state}
         {zipcode}-{zip_ext}
</s>
'''
 
prompt3 = '''
### Input: 
Name: {first_name}, {last_name}
Prompt: Provide the category of goods purchased by the above named person.
'''
response3 = '''
### Response:
Name: {first_name}, {last_name} bought goods belonging to the category {category}.
</s>
'''

prompt4 = '''
### Input: 
Name: {merchant}
Prompt: Was this merchant ever defrauded?.
'''
response4 = '''
### Response:
Merchant: {merchant} was defrauded at least once on {date} for ${amount} amount.
</s>
'''

prompt5 = '''
### Input: 
Name: {first_name}, {last_name}
Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
'''
response5 = '''
### Response:
{first_name}, {last_name} did commit Credit Card fraud on {date} for an amount of ${amount}.
</s>
'''

prompt6 = '''
### Input: 
Name: {merchant}
Prompt: Was this merchant ever defrauded?.
'''
response6 = '''
### Response:
Merchant: {merchant} was never defrauded.
</s>
'''

prompt7 = '''
### Input: 
Name: {first_name}, {last_name}
Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
'''
response7 = '''
### Response:
{first_name}, {last_name} did not ever commit Credit Card fraud.
</s>
'''

# %%
general_prompts=[prompt1, prompt2, prompt3]
general_responses = [response1, response2, response3]
fraud_prompts=[prompt4, prompt5]
fraud_responses = [response4, response5]
legit_prompts=[prompt6, prompt7]
legit_responses = [response6, response7]

# %%
def create_training_datapoints(df, instructions, inputs, outputs, texts):
    def add_new_training_datapoint(i, pi, rs):
        text = i + pi + rs
        instructions.append(i)
        inputs.append(pi)
        outputs.append(rs)
        texts.append(text)
        return
    
    for rec in df.iterrows():
        r = extract_transaction_info(rec)
        
        bi = basic_instruction.format(**r)
        ei = end_instruction.format(**r)
        
        if r['is_fraud']:
            instruction = bi + fraud_instruction + ei
        else:
            instruction = bi + legit_instruction + ei
        
        # Get a random train type for this record. We have 5 types of prompt
        # and we get a random number to train this specific record in a certain
        # prompt. 
        tt = np.random.randint(1,6)
        if tt in [1, 2, 3]:
            pi = general_prompts[tt-1].format(**r)
            rs = general_responses[tt-1].format(**r)
        elif tt in [4, 5]:
            if r['is_fraud']:
                pi = fraud_prompts[tt-4].format(**r)
                rs = fraud_responses[tt-4].format(**r)
            else:
                pi = legit_prompts[tt-4].format(**r)
                rs = legit_responses[tt-4].format(**r)
        add_new_training_datapoint(instruction, pi, rs)

# %%
inputs       = []
outputs      = []
instructions = []
texts        = []

# %%
create_training_datapoints(cdf, instructions, inputs, outputs, texts)

# %%
print(len(texts), len(cdf), len(instructions))
# Out:
# 5000 5000 5000

# %%
count=0
for text in texts:
    print(text)
    count +=1
    if count >= 20:
        break
# Out:
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Jacqueline, Curry who is a Female.
# Jacqueline, Curry's Date of Birth is 1990-11-23 and she lives in 3047 Jeff Place, Marathon, TX, 79842-3591, and works as a Lexicographer.
# She used the Credit Card with the Number 38588538868506 on 2020-02-10 to buy goods categorized as shopping_pos from the merchant Daugherty, Pouros and Beahan, and paid $9.76.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Jacqueline, Curry
# Prompt: Provide the category of goods purchased by the above named person.
#
# ### Response:
# Name: Jacqueline, Curry bought goods belonging to the category shopping_pos.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Christina, Rose who is a Female.
# Christina, Rose's Date of Birth is 1983-07-10 and she lives in 1984 Taylor Island Suite 836, Falls Church, VA, 22046-6699, and works as a Chartered accountant.
# She used the Credit Card with the Number 4635330563105903 on 2019-04-20 to buy goods categorized as kids_pets from the merchant Gottlieb Group, and paid $69.19.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Christina, Rose
# Credit Card Number: 4635330563105903
# Prompt: Provide the complete address including the zip code of this Credit Card owner.
#
# ### Response:
# Street Address: 1984 Taylor Island Suite 836
# City: Falls Church
# State: VA,
# Zipcode: 22046-6699
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Patricia, Gonzalez who is a Female.
# Patricia, Gonzalez's Date of Birth is 1967-03-30 and she lives in 8973 Mark Drive, Stephensport, KY, 40170-5357, and works as a Chartered public finance accountant.
# She used the Credit Card with the Number 180064817343047 on 2020-03-12 to buy goods categorized as shopping_net from the merchant Boyer PLC, and paid $1.01.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Patricia, Gonzalez
# Credit Card Number: 180064817343047
# Prompt: Provide the complete address including the zip code of this Credit Card owner.
#
# ### Response:
# Street Address: 8973 Mark Drive
# City: Stephensport
# State: KY,
# Zipcode: 40170-5357
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Rebecca, Butler who is a Female.
# Rebecca, Butler's Date of Birth is 1966-06-07 and she lives in 0665 Lisa Alley, Winger, MN, 56592-8791, and works as a Applications developer.
# She used the Credit Card with the Number 30175986190993 on 2019-12-22 to buy goods categorized as shopping_pos from the merchant Pagac LLC, and paid $9.95.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Pagac LLC
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Pagac LLC was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Antonio, Koch who is a Male.
# Antonio, Koch's Date of Birth is 1989-11-24 and he lives in 8738 Richard Brooks, Moab, UT, 84532-9991, and works as a Location manager.
# He used the Credit Card with the Number 3518758680062249 on 2019-10-12 to buy goods categorized as entertainment from the merchant Fadel, Mertz and Rippin, and paid $3.32.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 3518758680062249
# Prompt: Provide the first name, last name and the address of the provided Credit Card owner.
#
# ### Response:
# Name: Antonio, Koch
# Address: 8738 Richard Brooks
#          Moab, UT
#          84532-9991
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Christopher, Horn who is a Male.
# Christopher, Horn's Date of Birth is 1926-06-26 and he lives in 956 Sanchez Highway, Mallie, KY, 41836-5106, and works as a Facilities manager.
# He used the Credit Card with the Number 36078114201167 on 2019-08-05 to buy goods categorized as health_fitness from the merchant Adams-Barrows, and paid $46.29.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name:

# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 4642255475285942
# Prompt: Provide the first name, last name and the address of the provided Credit Card owner.
#
# ### Response:
# Name: Sabrina, Johnson
# Address: 320 Nicholson Orchard
#          Thompson, UT
#          84540-6509
# </s>

# %%
cdf['Instructions'] = instructions
cdf['Input'] = inputs
cdf['Output'] = outputs
cdf['text'] = texts
cdf = cdf.sample(frac=1).reset_index(drop=True)
cdf
# Out:
#      trans_date_trans_time            cc_num  \
# 0      2019-07-06 18:31:52  3506040590383211
# 1      2019-05-23 01:47:36  4003989662068504
# 2      2019-03-25 22:19:01  5301645381939419
# 3      2019-09-08 18:06:03    30074693890476
# 4      2020-04-02 01:35:50  4060579726528237
# ...                    ...               ...
# 4995   2019-02-25 18:10:43  3587960728692500
# 4996   2019-07-28 22:27:31  6501313409525696
# 4997   2019-07-08 22:50:43  3556613125071656
# 4998   2019-04-07 00:44:48  6011252220172077
# 4999   2019-11-18 18:43:57  2285066385084291
#
#                                merchant       category      amt    first  \
# 0      fraud_Nicolas, Hills and McGlynn  entertainment    78.97  Michael
# 1                      fraud_Spinka Inc    grocery_net    78.16    Chris
# 2                   fraud_Heathcote LLC   shopping_net   932.41      Joe
# 3                    fraud_Waelchi-Wolf      kids_pets     1.81   Kelsey
# 4                  fraud_Kutch and Sons    grocery_pos   100.53   Steven
# ...                                 ...            ...      ...      ...
# 4995                    fraud_Kuhic LLC   shopping_net  1021.53    Kathy
# 4996  fraud_Eichmann, Hayes and Treutel         travel    11.46   Carrie
# 4997    fraud_Parker, Nolan and Trantow  entertainment    12.01     Jose
# 4998                 fraud_Rau and Sons    grocery_pos    84.64   Melvin
# 4999                fraud_Dibbert-Green  entertainment     4.29  Richard
#
#           last gender                           street          city state  \
# 0       Orozco      M  13956 Hughes Causeway Suite 124         Alder    MT
# 1        White      M              98897 Bennett Lodge      Bessemer    AL
# 2        Allen      M        368 Rollins Fort Apt. 076        Aurora    CO
# 3     Richards      F      889 Sarah Station Suite 624       Holcomb    KS
# 4      Sanders      M                    25955 Amy Via       Ozawkie    KS
# ...        ...    ...                              ...           ...   ...
# 4995    Hughes      F    02110 Lucas Freeway Suite 517  Battle Creek    IA
# 4996     Lewis      F  28925 Powell Mountains Apt. 762         Pecos    TX
# 4997   Vasquez      M              572 Davis Mountains  Lake Jackson    TX
# 4998    Wright      M      210 Dean Causeway Suite 130         Alton    IA
# 4999     Brown      M       17819 Jose Mount Suite 657    Heidelberg    MS
#
#         zip  zip_ext      lat      long  city_pop  \
# 0     59710     3318  45.1939 -112.0568       286
# 1     35022     7091  33.3224  -86.9657     71463
# 2     80019     2286  39.7656 -104.7069    389246
# 3     67851     7694  37.9931 -100.9893      2691
# 4     66070     6203  39.2136  -95.4404      2661
# ...     ...      ...      ...       ...       ...
# 4995  51006     5263  42.3327  -95.6045      1075
# 4996  79772     1298  31.4467 -103.5791     12747
# 4997  77566     9243  29.0393  -95.4401     28739
# 4998  51003     4183  42.9782  -96.0173      1700
# 4999  39439     7573  31.8820  -88.9981      4573
#
#                                       job         dob  \
# 0                          Chief of Staff  1989-03-09
# 1               Radio broadcast assistant  1989-02-08
# 2             Industrial/product designer  1938-08-07
# 3                         Arboriculturist  1993-08-16
# 4                        Theatre director  1948-11-14
# ...                                   ...         ...
# 4995             Teacher, early years/pre  1997-01-02
# 4996                 Merchandiser, retail  1987-05-05
# 4997                       Futures trader  1999-12-27
# 4998                       Engineer, land  2001-12-19
# 4999  Exhibitions officer, museum/gallery  1988-02-15
#
#                              trans_num   unix_time  merch_lat  merch_long  \
# 0     f78fb6a2861cc1ecfdcaef34608cf0d5  1341599512  46.125969 -112.591133
# 1     bd68dc23a0ec9862d3d2373a7a71c68b  1337737656  33.516155  -86.141047
# 2     10867f773da784ca129f9096e4193f3b  1332713941  39.976180 -105.346222
# 3     97fccc0587496db0f6f512efa88cd8a2  1347127563  38.685702 -101.362142
# 4     98bb8682d6478370b243578cb8b55320  1364866550  39.613417  -95.754739
# ...                                ...         ...        ...         ...
# 4995  09d16c1f7a60ce980e3fc0461c8b3c06  1330193443  42.253287  -95.225571
# 4996  a260b628b7f661a988058216446ff7b9  1343514451  31.487055 -102.820143
# 4997  9cc61073cfc1d87f618db419aa7d4bc1  1341787843  29.922286  -96.382531
# 4998  c49418b12a7910f9bec025a1e29e03b9  1333759488  42.822608  -95.637010
# 4999  ba75199b82db22d15979ff2dfdd1f8d7  1353264237  31.332876  -88.484431
#
#       is_fraud                                       Instructions  \
# 0            0  <s>\n### Instruction:\nThe data provided below...
# 1            0  <s>\n### Instruction:\nThe data provided below...
# 2            1  <s>\n### Instruction:\nThe data provided below...
# 3            0  <s>\n### Instruction:\nThe data provided below...
# 4            0  <s>\n### Instruction:\nThe data provided below...
# ...        ...                                                ...
# 4995         1  <s>\n### Instruction:\nThe data provided below...
# 4996         1  <s>\n### Instruction:\nThe data provided below...
# 4997         0  <s>\n### Instruction:\nThe data provided below...
# 4998         0  <s>\n### Instruction:\nThe data provided below...
# 4999         0  <s>\n### Instruction:\nThe data provided below...
#
#                                                   Input  \
# 0     \n### Input: \nName: Schoen Ltd\nPrompt: Was t...
# 1     \n### Input: \nName: Dakota, Maldonado\nPrompt...
# 2     \n### Input: \nName: Cesar, Smith\nCredit Card...
# 3     \n### Input: \nName: Murray-Smitham\nPrompt: W...
# 4     \n### Input: \nName: Brandon, Pittman\nCredit ...
# ...                                                 ...
# 4995  \n### Input: \nName: Nathan, Mendoza\nPrompt: ...
# 4996  \n### Input: \nCredit Card: 4170689372027579\n...
# 4997  \n### Input: \nName: Amber, Lewis\nCredit Card...
# 4998  \n### Input: \nName: Christopher, Horn\nCredit...
# 4999  \n### Input: \nName: Kihn-Schuster\nPrompt: Wa...
#
#                                                  Output  \
# 0     \n### Response:\nMerchant: Schoen Ltd was neve...
# 1     \n### Response:\nName: Dakota, Maldonado bough...
# 2     \n### Response:\nStreet Address: 901 Ariel Poi...
# 3     \n### Response:\nMerchant: Murray-Smitham was ...
# 4     \n### Response:\nStreet Address: 2881 Frey Vil...
# ...                                                 ...
# 4995  \n### Response:\nNathan, Mendoza did not ever ...
# 4996  \n### Response:\nName: Samuel, Frey\nAddress: ...
# 4997  \n### Response:\nStreet Address: 6296 John Key...
# 4998  \n### Response:\nStreet Address: 956 Sanchez H...
# 4999  \n### Response:\nMerchant: Kihn-Schuster was n...
#
#                                                    text
# 0     <s>\n### Instruction:\nThe data provided below...
# 1     <s>\n### Instruction:\nThe data provided below...
# 2     <s>\n### Instruction:\nThe data provided below...
# 3     <s>\n### Instruction:\nThe data provided below...
# 4     <s>\n### Instruction:\nThe data provided below...
# ...                                                 ...
# 4995  <s>\n### Instruction:\nThe data provided below...
# 4996  <s>\n### Instruction:\nThe data provided below...
# 4997  <s>\n### Instruction:\nThe data provided below...
# 4998  <s>\n### Instruction:\nThe data provided below...
# 4999  <s>\n### Instruction:\nThe data provided below...
#
# [5000 rows x 27 columns]

# %%
f"We have {len(cdf)} records, with unique credit cards={len(np.unique(cdf['cc_num']))}"
# Out:
# 'We have 5000 records, with unique credit cards=920'

# %%
# Split this into 70 30 for training and testing
mask = np.random.rand(len(cdf)) < 0.7
traindf = cdf[mask]
testdf  = cdf[~mask]

# %%
traindf.to_csv('../datasets/credit_card_fraud_train_dataset_v2.csv', index=False)

# %%
sanitydf = pd.read_csv('../datasets/credit_card_fraud_train_dataset_v2.csv')

# %%
x=sanitydf.sample(10)
for msg in x['text']:
    print(msg)
# Out:
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Krystal, Gamble who is a Female.
# Krystal, Gamble's Date of Birth is 1964-02-15 and she lives in 47152 Clayton Burg, Manchester, MD, 21102-9492, and works as a Clinical research associate.
# She used the Credit Card with the Number 180065479077096 on 2019-10-27 to buy goods categorized as grocery_pos from the merchant Cole PLC, and paid $84.56.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Cole PLC
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Cole PLC was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Gary, Martinez who is a Male.
# Gary, Martinez's Date of Birth is 1997-03-12 and he lives in 03512 Jackson Ports, Reno, NV, 89512-9972, and works as a Immunologist.
# He used the Credit Card with the Number 4364010865167176 on 2019-11-25 to buy goods categorized as grocery_pos from the merchant Strosin-Cruickshank, and paid $283.17.
# This is a fradulent transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Gary, Martinez
# Credit Card Number: 4364010865167176
# Prompt: Provide the complete address including the zip code of this Credit Card owner.
#
# ### Response:
# Street Address: 03512 Jackson Ports
# City: Reno
# State: NV,
# Zipcode: 89512-9972
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Tami, Forbes who is a Female.
# Tami, Forbes's Date of Birth is 1963-12-29 and she lives in 5204 Robinson Plaza Suite 897, Barnstable, MA, 2630-5618, and works as a Counselling psychologist.
# She used the Credit Card with the Number 4826655832045236 on 2019-11-11 to buy goods categorized as misc_net from the merchant Brown PLC, and paid $822.17.
# This is a fradulent transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Brown PLC
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Brown PLC was defrauded at least once on 2019-11-11 for $822.17 amount.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Bianca, Novak who is a Female.
# Bianca, Novak's Date of Birth is 1947-08-14 and she lives in 0953 David Skyway, Cuthbert, GA, 39840-1686, and works as a Fitness centre manager.
# She used the Credit Card with the Number 4670613943676271 on 2019-11-21 to buy goods categorized as gas_transport from the merchant Christiansen, Goyette and Schamberger, and paid $83.35.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Bianca, Novak
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Bianca, Novak did not ever commit Credit Card fraud.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Catherine, Weber who is a Female.
# Catherine, Weber's Date of Birth is 1968-06-24 and she lives in 74890 Rodriguez Springs Apt. 540, West Henrietta, NY, 14586-7672, and works as a Teacher, primary school.
# She used the Credit Card with the Number 213161293389774 on 2020-04-27 to buy goods categorized as gas_transport from the merchant Bernhard Inc, and paid $89.82.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Bernhard Inc
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Bernhard Inc was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Michael, Olson who is a Male.
# Michael, Olson's Date of Birth is 1966-02-13 and he lives in 558 Michael Estates, Luray, MO, 63453-5367, and works as a Town planner.
# He used the Credit Card with the Number 30560609640617 on 2020-06-16 to buy goods categorized as misc_net from the merchant Bernier, Volkman and Hoeger, and paid $739.17.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 30560609640617
# Prompt: Provide the first name, last name and the address of the provided Credit Card owner.
#
# ### Response:
# Name: Michael, Olson
# Address: 558 Michael Estates
#          Luray, MO
#          63453-5367
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Monica, Lane who is a Female.
# Monica, Lane's Date of Birth is 1970-04-17 and she lives in 3270 Scott Islands, East Andover, ME, 4226-7283, and works as a Animal nutritionist.
# She used the Credit Card with the Number 213161869125933 on 2019-05-02 to buy goods categorized as kids_pets from the merchant Fahey Inc, and paid $6.03.
# This is a fradulent transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Monica, Lane
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Monica, Lane did commit Credit Card fraud on 2019-05-02 for an amount of $6.03.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Ashley, Robinson who is a Female.
# Ashley, Robinson's Date of Birth is 1935-08-15 and she lives in 1007 Colton Forks, Hopewell, VA, 23860-1096, and works as a Purchasing manager.
# She used the Credit Card with the Number 3592325941359225 on 2020-04-01 to buy goods categorized as shopping_net from the merchant Kerluke-Abshire, and paid $862.0.
# This is a fradulent transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Kerluke-Abshire
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Kerluke-Abshire was defrauded at least once on 2020-04-01 for $862.0 amount.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Terri, Bailey who is a Female.
# Terri, Bailey's Date of Birth is 1991-10-04 and she lives in 508 Erin Mount, Daly City, CA, 94015-7877, and works as a Buyer, industrial.
# She used the Credit Card with the Number 6011148190095209 on 2019-12-23 to buy goods categorized as shopping_net from the merchant Little, Gutmann and Lynch, and paid $256.44.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Little, Gutmann and Lynch
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Little, Gutmann and Lynch was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# The data provided below is for a credit card transaction made by Stephanie, Cummings who is a Female.
# Stephanie, Cummings's Date of Birth is 1926-08-27 and she lives in 1025 Robin Square, Ash Flat, AR, 72513-2315, and works as a Hydrologist.
# She used the Credit Card with the Number 4502539526809429801 on 2019-11-30 to buy goods categorized as home from the merchant Pollich LLC, and paid $199.29.
# This is a legitimate transaction.
# Complete the Prompt given below using the above information and the additional Input information provided in the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Stephanie, Cummings
# Credit Card Number: 4502539526809429801
# Prompt: Provide the complete address including the zip code of this Credit Card owner.
#
# ### Response:
# Street Address: 1025 Robin Square
# City: Ash Flat
# State: AR,
# Zipcode: 72513-2315
# </s>

# %%
testdf.to_csv('../datasets/credit_card_fraud_test_dataset_v2.csv', index=False)

# %%
print(len(texts))
# Out:
# 5000

# %%
max_len = 0
for text in texts:
    if len(text) > max_len:
        max_len = len(text)
print(max_len)
# Out:
# 985
