# %%
import pandas as pd
import numpy as np
import random
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# %%
with open('../datasets/fraudTrainWithExtZip.csv') as fd:
    numcols = len(fd.readline().split(','))
df = pd.read_csv('../datasets/fraudTrainWithExtZip.csv', usecols=range(1,numcols))

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'zip_ext',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
display(df.head(5))
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city state    zip  zip_ext  \
# 0                561 Perry Cove  Moravian Falls    NC  28654     6204
# 1  43039 Riley Greens Suite 393          Orient    WA  99160     8487
# 2      594 White Dale Suite 530      Malad City    ID  83252     9323
# 3   9443 Cynthia Court Apt. 038         Boulder    MT  59632     9670
# 4              408 Bradley Rest        Doe Hill    VA  24433     3197
#
#        lat      long  city_pop                                job         dob  \
# 0  36.0788  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1  48.8878 -118.2105       149  Special educational needs teacher  1978-06-21
# 2  42.1808 -112.2620      4154        Nature conservation officer  1962-01-19
# 3  46.2306 -112.1138      1939                    Patent attorney  1967-01-12
# 4  38.4207  -79.4629        99     Dance movement psychotherapist  1986-03-28
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
num_records = 5000
scale_fraud_proportion = 20

# %%
# Reduce the number of records to above value
# We need to keep the proportion of fraud vs not fraud records the same.
fraud_prop = np.sum(df['is_fraud'] == 1)/len(df)

# Separate the fraud and not fraud records
df_fraud = df[ df['is_fraud'] == 1 ]
df_not_fraud = df[ df['is_fraud'] == 0 ]

# Get a sampling from each in the proportion and combine
fraud_count = int(num_records*fraud_prop)*scale_fraud_proportion
not_fraud_count = num_records - fraud_count

print(fraud_count, not_fraud_count)
# Sample the fraud and not fraud records
fraud_selected = df_fraud.sample(fraud_count, replace=False).reset_index(drop=True)
not_fraud_selected = df_not_fraud.sample(not_fraud_count, replace=False).reset_index(drop=True)

print(len(fraud_selected), len(not_fraud_selected))
# Combined df of both types

cdf = pd.concat([fraud_selected,not_fraud_selected])
print(len(cdf))
# Out:
# 560 4440
# 560 4440
# 5000

# %%
df_fraud = cdf[ cdf['is_fraud'] == 1 ]
df_not_fraud = cdf[ cdf['is_fraud'] == 0 ]
print(len(fraud_selected), len(not_fraud_selected))
# Out:
# 560 4440

# %%
# Shuffle the records
cdf = cdf.sample(frac=1).reset_index(drop=True)

# %%
def extract_transaction_info(rec):
    r = {}
    r['date'] = str(rec[1]['trans_date_trans_time']).split(' ')[0]
    r['cc_num'] = str(rec[1]['cc_num'])
    r['amount'] = str(rec[1]['amt'])
    r['first_name'] = str(rec[1]['first'])
    r['last_name'] = str(rec[1]['last'])
    if str(rec[1]['gender']) == 'M':
        r['gender'] = 'Male'
        r['pronoun'] = 'he'
        r['Pronoun'] = 'He'
    else:
        r['gender'] = 'Female'
        r['pronoun'] = 'she' 
        r['Pronoun'] = 'She'
    r['merchant'] = str(rec[1]['merchant'])
    if r['merchant'].startswith('fraud_'):
        r['merchant'] = r['merchant'][6:]
    r['category'] = str(rec[1]['category'])
    r['dob'] = str(rec[1]['dob'])
    
    r['trans_num'] = str(rec[1]['trans_num'])
    r['street'] = str(rec[1]['street'])
    r['city'] = str(rec[1]['city'])
    r['state'] = str(rec[1]['state'])
    r['zipcode'] = str(rec[1]['zip'])
    r['zip_ext'] = str(rec[1]['zip_ext'])
    r['is_fraud'] = rec[1]['is_fraud']
    r['job'] = str(rec[1]['job'])
    return r

# %%
basic_instruction = '''<s>
### Instruction:
{first_name},{last_name}, a {gender} born {dob} lives at {street},{city},{state},{zipcode}-{zip_ext},works as a {job},used Credit Card # {cc_num} on {date} bought {category} goods from {merchant} costing ${amount}.
'''

fraud_instruction = '''Type: fraud.'''
legit_instruction = '''Type: legit.'''

end_instruction   = '''
Finish the Prompt.
'''
prompt1 = '''
### Input: 
Name:{first_name},{last_name}
Credit Card # {cc_num}
Prompt:Give Addr & Zip.
'''
response1 = '''
### Response:
ST:{street}
CTY:{city}
ST:{state}
ZIP:{zipcode}-{zip_ext}
</s>
'''

prompt2 = '''
### Input:
Credit Card #: {cc_num}
Prompt:Provide first,last name & Addr.
'''
response2 = '''
### Response:
Name:{first_name},{last_name}
Addr:{street}
{city},{state}
{zipcode}-{zip_ext}
</s>
'''
 
prompt3 = '''
### Input: 
Name:{first_name},{last_name}
Prompt:Provide the category of goods.
'''
response3 = '''
### Response:
Name:{first_name},{last_name} bought goods in {category}.
</s>
'''

prompt4 = '''
### Input: 
Name:{merchant}
Prompt:Was this merchant defrauded?.
'''
response4 = '''
### Response:
{merchant} was defrauded on {date} for ${amount}.
</s>
'''

prompt5 = '''
### Input: 
Name:{first_name},{last_name}
Prompt:If the person defrauded,give date and $amount.
'''
response5 = '''
### Response:
{first_name},{last_name} defrauded on {date} for ${amount}.
</s>
'''

prompt6 = '''
### Input: 
Name:{merchant}
Prompt:Was this merchant defrauded?
'''
response6 = '''
### Response:
{merchant} wasn't defrauded.
</s>
'''

prompt7 = '''
### Input: 
Name:{first_name},{last_name}
Prompt:If the person defrauded,give date and $amount.
'''
response7 = '''
### Response:
{first_name},{last_name} didn't defraud.
</s>
'''

# %%
general_prompts=[prompt1, prompt2, prompt3]
general_responses = [response1, response2, response3]
fraud_prompts=[prompt4, prompt5]
fraud_responses = [response4, response5]
legit_prompts=[prompt6, prompt7]
legit_responses = [response6, response7]

# %%
def create_training_datapoints(df, instructions, inputs, outputs, texts):
    def add_new_training_datapoint(i, pi, rs):
        text = i + pi + rs
        instructions.append(i)
        inputs.append(pi)
        outputs.append(rs)
        texts.append(text)
        return
    
    for rec in df.iterrows():
        r = extract_transaction_info(rec)
        
        bi = basic_instruction.format(**r)
        ei = end_instruction.format(**r)
        
        if r['is_fraud']:
            instruction = bi + fraud_instruction + ei
        else:
            instruction = bi + legit_instruction + ei
        
        # Get a random train type for this record. We have 5 types of prompt
        # and we get a random number to train this specific record in a certain
        # prompt. 
        tt = np.random.randint(1,6)
        if tt in [1, 2, 3]:
            pi = general_prompts[tt-1].format(**r)
            rs = general_responses[tt-1].format(**r)
        elif tt in [4, 5]:
            if r['is_fraud']:
                pi = fraud_prompts[tt-4].format(**r)
                rs = fraud_responses[tt-4].format(**r)
            else:
                pi = legit_prompts[tt-4].format(**r)
                rs = legit_responses[tt-4].format(**r)
        add_new_training_datapoint(instruction, pi, rs)

# %%
inputs       = []
outputs      = []
instructions = []
texts        = []

# %%
create_training_datapoints(cdf, instructions, inputs, outputs, texts)

# %%
print(len(texts), len(cdf), len(instructions))
# Out:
# 5000 5000 5000

# %%
count=0
for text in texts:
    print(text)
    count +=1
    if count >= 20:
        break
# Out:
# <s>
# ### Instruction:
# Rick,Martinez, a Male born 1970-03-13 lives at 062 Poole Hollow Apt. 815,Deadwood,SD,57732-7816,works as a Multimedia programmer,used Credit Card # 372246459334925 on 2019-06-01 bought misc_pos goods from Dickinson-Rempel costing $6.29.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Rick,Martinez
# Prompt:If the person defrauded,give date and $amount.
#
# ### Response:
# Rick,Martinez didn't defraud.
# </s>
#
# <s>
# ### Instruction:
# Ryan,Joseph, a Male born 1986-08-17 lives at 8850 Jessica Center,Atlantic,VA,23303-1631,works as a Geologist, engineering,used Credit Card # 4446368897795790 on 2019-01-23 bought misc_net goods from McGlynn-Heathcote costing $104.89.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Ryan,Joseph
# Credit Card # 4446368897795790
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:8850 Jessica Center
# CTY:Atlantic
# ST:VA
# ZIP:23303-1631
# </s>
#
# <s>
# ### Instruction:
# William,Perry, a Male born 1994-05-31 lives at 458 Phillips Island Apt. 768,Denham Springs,LA,70726-7977,works as a Herbalist,used Credit Card # 4005676619255478 on 2019-11-30 bought gas_transport goods from Prohaska-Murray costing $89.4.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Prohaska-Murray
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Prohaska-Murray wasn't defrauded.
# </s>
#
# <s>
# ### Instruction:
# Charles,Carrillo, a Male born 1995-04-19 lives at 17547 Stephen Turnpike Apt. 846,Hawthorne,CA,90250-5684,works as a Editor, magazine features,used Credit Card # 4683520018489354 on 2019-02-06 bought personal_care goods from Schiller Ltd costing $7.9.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Schiller Ltd
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Schiller Ltd wasn't defrauded.
# </s>
#
# <s>
# ### Instruction:
# Jennifer,Black, a Female born 1981-08-29 lives at 2870 Bean Terrace Apt. 756,Thomas,WV,26292-7387,works as a Forensic psychologist,used Credit Card # 630424987505 on 2019-09-04 bought shopping_pos goods from Quitzon, Green and Bashirian costing $3.67.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Jennifer,Black
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Jennifer,Black bought goods in shopping_pos.
# </s>
#
# <s>
# ### Instruction:
# Angela,West, a Female born 1968-05-29 lives at 9471 Wong Islands,Mansfield,OH,44902-3471,works as a Press photographer,used Credit Card # 4550599031376731 on 2019-12-16 bought entertainment goods from Donnelly LLC costing $4.24.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Angela,West
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Angela,West bought goods in entertainment.
# </s>
#
# <s>
# ### Instruction:
# Teresa,Stein, a Female born 1974-12-05 lives at 2838 White Fields Apt. 473,Brunson,SC,29911-1985,works as a Social researcher,used Credit Card # 3527536963490470 on 2019-11-06 bought health_fitness goods from Adams-Barrows costing $145.17.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Teresa,Stein
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Teresa,Stein bought goods in health_fitness.
# </s>
#
# <s>
# ### Instruction:
# Kristen,Hanson, a Female born 1985-06-18 lives at 26544 Andrea Glen,Goodrich,MI,48438-7526,works as a Learning disability nurse,used Credit Card # 372509258176510 on 2019-06-11 bought health_fitness goods from Fadel Inc costing $31.58.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Kristen,Hanson
# Credit Card # 372509258176510
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:26544 Andrea Glen
# CTY:Goodrich
# ST:MI
# ZIP:48438-7526
# </s>
#
# <s>
# ### Instruction:
# Matthew,Young, a Male born 1955-05-06 lives at 8840 Miller Port Suite 645,Indian Wells,CA,92210-5947,works as a Learning mentor,used Credit Card # 3560697798177746 on 2019-08-30 bought grocery_net goods from Swift, Bradtke and Marquardt costing $109.96.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Matthew,Young
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Matthew,Young bought goods in grocery_net.
# </s>
#
# <s>
# ### Instruction:
# Lance,Wagner, a Male born 1975-06-01 lives at 6003 Brady Shoal Apt. 449,Irwinton,GA,31042-5048,works as a Film/video editor,used Credit Card # 4935858973307492 on 2020-03-18 bought grocery_pos goods from Schumm, Bauch and Ondricka costing $96.15.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Credit Card #: 4935858973307492
# Prompt:Provide first,last name & Addr.
#
# ### Response:
# Name:Lance,Wagner
# Addr:6003 Brady Shoal Apt. 449
# Irwinton,GA
# 31042-5048
# </s>
#
# <s>
# ### Instruction:
# Jacqueline,Marsh, a Female born 1951-02-05 lives at 950 Sheryl Spurs,Dunlevy,PA,15432-3733,works as a Mining engineer,used Credit Card # 6011388901471808 on 2020-02-02 bought misc_net goods from Stehr, Jewess and Schimmel costing $32.47.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Jacqueline,Marsh
# Credit Card # 6011388901471808
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:950 Sheryl Spurs
# CTY:Dunlevy
# ST:PA
# ZIP:15432-3733
# </s>
#
# <s>
# ### Instruction:
# Samuel,Farrell, a Male born 1977-06-14 lives at 428 Michael Tunnel Apt. 377,Cleveland,AL,35049-7892,works as a Aid worker,used Credit Card # 4149635823017 on 2019-06-13 bought entertainment goods from Cummerata-Hilpert costing $67.43.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Samuel,Farrell
# Credit Card # 4149635823017
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:428 Michael Tunnel Apt. 377
# CTY:Cleveland
# ST:AL
# ZIP:35049-7892
# </s>
#
# <s>
# ### Instruction:
# Alicia,Morales, a Female born 1939-11-04 lives at 4456 Dunn Roads,Meredith,CO,81642-6871,works as a Public relations account executive,used Credit Card # 4430881574719618 on 2019-02-28 bought home goods from Quitzon-Goyette costing $45.13.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Alicia,Morales
# Credit Card # 4430881574719618
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:4456 Dunn Roads
# CTY:Meredith
# ST:CO
# ZIP:81642-6871
# </s>
#
# <s>
# ### Instruction:
# Christopher,Farrell, a Male born 1991-01-01 lives at 97070 Anderson Land,Haines City,FL,33844-9563,works as a Exercise physiologist,used Credit Card # 4822367783500458 on 2020-03-04 bought shopping_pos goods from Lesch Ltd costing $8.68.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Credit Card #: 4822367783500458
# Prompt:Provide first,last name & Addr.
#
# ### Response:
# Name:Christopher,Farrell
# Addr:97070 Anderson Land
# Haines City,FL
# 33844-9563
# </s>
#
# <s>
# ### Instruction:
# William,Perry, a Male born 1994-05-31 lives at 458 Phillips Island Apt. 768,Denham Springs,LA,70726-7977,works as a Herbalist,used Credit Card # 4005676619255478 on 2019-07-31 bought shopping_net goods from Romaguera, Cruickshank and Greenholt costing $5.2.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:William,Perry
# Credit Card # 4005676619255478
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:458 Phillips Island Apt. 768
# CTY:Denham Springs
# ST:LA
# ZIP:70726-7977
# </s>
#
# <s>
# ### Instruction:
# Margaret,Mendez, a Female born 1978-10-01 lives at 7952 Karen Pike,De Soto,KS,66018-1962,works as a Chief Executive Officer,used Credit Card # 4792627764422477317 on 2019-12-01 bought misc_net goods from Bernier, Volkman and Hoeger costing $119.36.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Margaret,Mendez
# Prompt:If the person defrauded,give date and $amount.
#
# ### Response:
# Margaret,Mendez didn't defraud.
# </s>
#
# <s>
# ### Instruction:
# Christopher,Gilbert, a Male born 1970-07-20 lives at 20937 Reed Lakes Apt. 271,Washington,DC,20012-4325,works as a Optician, dispensing,used Credit Card # 374125201044065 on 2019-07-13 bought grocery_pos goods from Goldner, Kovacek and Abbott costing $109.58.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Christopher,Gilbert
# Credit Card # 374125201044065
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:20937 Reed Lakes Apt. 271
# CTY:Washington
# ST:DC
# ZIP:20012-4325
# </s>
#
# <s>
# ### Instruction:
# Francisco,Kemp, a Male born 1985-03-31 lives at 9554 Flores Drive,Arnold,MO,63010-2159,works as a Land/geomatics surveyor,used Credit Card # 3512365128314616 on 2019-01-18 bought grocery_net goods from Paucek-Wiza costing $66.84.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Francisco,Kemp
# Prompt:If the person defrauded,give date and $amount.
#
# ### Response:
# Francisco,Kemp didn't defraud.
# </s>
#
# <s>
# ### Instruction:
# Donna,Moreno, a Female born 1991-10-22 lives at 32301 Albert River Suite 364,Ronceverte,WV,24970-8205,works as a Statistician,used Credit Card # 346273234529002 on 2019-07-06 bought shopping_pos goods from Morissette PLC costing $4.03.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Donna,Moreno
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Donna,Moreno bought goods in shopping_pos.
# </s>
#
# <s>
# ### Instruction:
# Sherry,Martinez, a Female born 1945-09-20 lives at 144 Yu Locks Apt. 754,Garrattsville,NY,13342-5166,works as a Naval architect,used Credit Card # 502012776709 on 2019-02-26 bought home goods from Kling, Howe and Schneider costing $25.35.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Kling, Howe and Schneider
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Kling, Howe and Schneider wasn't defrauded.
# </s>

# %%
cdf['Instructions'] = instructions
cdf['Input'] = inputs
cdf['Output'] = outputs
cdf['text'] = texts
cdf = cdf.sample(frac=1).reset_index(drop=True)
cdf
# Out:
#      trans_date_trans_time               cc_num  \
# 0      2019-03-03 23:49:31         503874407318
# 1      2019-04-29 19:18:26     3575789281659026
# 2      2019-02-22 23:05:46         573860193545
# 3      2019-05-30 15:10:24  4102003771126577611
# 4      2019-07-01 03:48:28     3593118134380341
# ...                    ...                  ...
# 4995   2019-08-21 16:05:50     6011893664860915
# 4996   2019-01-30 22:28:40     6511349151405438
# 4997   2020-03-17 21:43:09     3504178999463051
# 4998   2019-12-01 21:26:35     6011438889172900
# 4999   2020-03-10 04:15:49      180036456789979
#
#                                  merchant       category      amt      first  \
# 0                          fraud_Howe PLC  entertainment    97.84     Andrew
# 1                   fraud_Kutch-Wilderman           home   158.55    Lindsay
# 2                   fraud_Bashirian Group   shopping_net  1014.39   Cristian
# 3                  fraud_Pfeffer and Sons   shopping_pos     7.61    William
# 4                        fraud_Barton Inc    grocery_pos   159.85      Laura
# ...                                   ...            ...      ...        ...
# 4995  fraud_Reinger, Weissnat and Strosin    food_dining    51.90       Erin
# 4996                  fraud_Berge-Ullrich           home    16.62     Robert
# 4997    fraud_Bins, Balistreri and Beatty   shopping_pos     3.70       Drew
# 4998                 fraud_Beier and Sons           home    56.90    Allison
# 4999                  fraud_Friesen-Stamm  gas_transport    72.00  Mackenzie
#
#             last gender                          street         city state  \
# 0          Mcgee      M      4130 Tiffany Glen Apt. 562  San Antonio    TX
# 1         Wilson      F           7618 Gonzales Mission   Centerview    MO
# 2          Jones      M      0423 Kirby Field Suite 623     Wilmette    IL
# 3     Fitzgerald      M     715 Courtney Pike Suite 932       Keller    TX
# 4          Casey      F                  6114 Moran Way      Steuben    ME
# ...          ...    ...                             ...          ...   ...
# 4995      Chavez      F            3379 Williams Common    Littleton    CO
# 4996      Nguyen      M              74835 Garner Point         Ruth    NV
# 4997      Garcia      M  70858 Jasmine Meadows Apt. 135         Lima    OH
# 4998       Allen      F             40624 Rebecca Spurs      De Witt    AR
# 4999     Salazar      F                982 Melissa Lock       Bagley    WI
#
#         zip  zip_ext      lat      long  city_pop                      job  \
# 0     78248     3602  29.5894  -98.5201   1595797      Exhibition designer
# 1     64019     6070  38.7897  -93.8702      2368     Electronics engineer
# 2     60091     1039  42.0765  -87.7246     27020      Trade mark attorney
# 3     76248     5926  32.9276  -97.2489     95035        Probation officer
# 4      4680     6752  44.4971  -67.9503      1131                     Make
# ...     ...      ...      ...       ...       ...                      ...
# 4995  80120     2496  39.5994 -105.0044    320420           Water engineer
# 4996  89319     2765  39.3426 -114.8859       450              Interpreter
# 4997  45801     9228  40.7641  -84.0973     86954  Copywriter, advertising
# 4998  72042     7986  34.2853  -91.3336      5161      Electrical engineer
# 4999  53801     5483  42.9207  -91.0685       878             Risk analyst
#
#              dob                         trans_num   unix_time  merch_lat  \
# 0     1975-12-28  23c4e5b951e16c7180911f39209570bb  1330818571  29.607340
# 1     1989-07-17  c9cbccc948d0717c43c187a4f5c63906  1335727106  38.001599
# 2     1986-07-23  a1c19e5aef273d8d7d0996fd16d24144  1329951946  41.631614
# 3     1987-06-13  43a41b6cb0224366ac2ad1b1f1516d70  1338390624  32.517510
# 4     1959-05-10  d2516c4998b6b94c39ae66467a8b080d  1341114508  45.056817
# ...          ...                               ...         ...        ...
# 4995  1975-07-31  22e847743acf88b6696883d6cbb8f427  1345565150  40.382482
# 4996  1946-08-24  739e6a60f5954c440967218cd89e54ec  1327962520  38.661703
# 4997  1992-07-23  18e8840d0a2e78baa1fee0e0e82e05dc  1363556589  40.429126
# 4998  1993-04-08  9a8b53cf3fe3ebe9309b3935bf870a04  1354397195  33.673732
# 4999  1974-11-20  1094d59b4b5e7335256dacae811ae071  1362888949  42.020702
#
#       merch_long  is_fraud                                       Instructions  \
# 0     -98.525947         0  <s>\n### Instruction:\nAndrew,Mcgee, a Male bo...
# 1     -93.965902         0  <s>\n### Instruction:\nLindsay,Wilson, a Femal...
# 2     -87.957429         1  <s>\n### Instruction:\nCristian,Jones, a Male ...
# 3     -96.271361         0  <s>\n### Instruction:\nWilliam,Fitzgerald, a M...
# 4     -67.678548         0  <s>\n### Instruction:\nLaura,Casey, a Female b...
# ...          ...       ...                                                ...
# 4995 -104.130688         0  <s>\n### Instruction:\nErin,Chavez, a Female b...
# 4996 -114.012676         0  <s>\n### Instruction:\nRobert,Nguyen, a Male b...
# 4997  -83.715432         0  <s>\n### Instruction:\nDrew,Garcia, a Male bor...
# 4998  -91.221191         0  <s>\n### Instruction:\nAllison,Allen, a Female...
# 4999  -91.369676         0  <s>\n### Instruction:\nMackenzie,Salazar, a Fe...
#
#                                                   Input  \
# 0     \n### Input: \nName:Howe PLC\nPrompt:Was this ...
# 1     \n### Input: \nName:Lindsay,Wilson\nCredit Car...
# 2     \n### Input: \nName:Bashirian Group\nPrompt:Wa...
# 3     \n### Input: \nName:Pfeffer and Sons\nPrompt:W...
# 4     \n### Input: \nName:Laura,Casey\nPrompt:Provid...
# ...                                                 ...
# 4995  \n### Input: \nName:Erin,Chavez\nPrompt:Provid...
# 4996  \n### Input: \nName:Berge-Ullrich\nPrompt:Was ...
# 4997  \n### Input: \nName:Drew,Garcia\nPrompt:If the...
# 4998  \n### Input:\nCredit Card #: 6011438889172900\...
# 4999  \n### Input:\nCredit Card #: 180036456789979\n...
#
#                                                  Output  \
# 0     \n### Response:\nHowe PLC wasn't defrauded.\n<...
# 1     \n### Response:\nST:7618 Gonzales Mission\nCTY...
# 2     \n### Response:\nBashirian Group was defrauded...
# 3     \n### Response:\nPfeffer and Sons wasn't defra...
# 4     \n### Response:\nName:Laura,Casey bought goods...
# ...                                                 ...
# 4995  \n### Response:\nName:Erin,Chavez bought goods...
# 4996  \n### Response:\nBerge-Ullrich wasn't defraude...
# 4997  \n### Response:\nDrew,Garcia didn't defraud.\n...
# 4998  \n### Response:\nName:Allison,Allen\nAddr:4062...
# 4999  \n### Response:\nName:Mackenzie,Salazar\nAddr:...
#
#                                                    text
# 0     <s>\n### Instruction:\nAndrew,Mcgee, a Male bo...
# 1     <s>\n### Instruction:\nLindsay,Wilson, a Femal...
# 2     <s>\n### Instruction:\nCristian,Jones, a Male ...
# 3     <s>\n### Instruction:\nWilliam,Fitzgerald, a M...
# 4     <s>\n### Instruction:\nLaura,Casey, a Female b...
# ...                                                 ...
# 4995  <s>\n### Instruction:\nErin,Chavez, a Female b...
# 4996  <s>\n### Instruction:\nRobert,Nguyen, a Male b...
# 4997  <s>\n### Instruction:\nDrew,Garcia, a Male bor...
# 4998  <s>\n### Instruction:\nAllison,Allen, a Female...
# 4999  <s>\n### Instruction:\nMackenzie,Salazar, a Fe...
#
# [5000 rows x 27 columns]

# %%
f"We have {len(cdf)} records, with unique credit cards={len(np.unique(cdf['cc_num']))}"
# Out:
# 'We have 5000 records, with unique credit cards=926'

# %%
# Split this into 70 30 for training and testing
mask = np.random.rand(len(cdf)) < 0.7
traindf = cdf[mask]
testdf  = cdf[~mask]

# %%
traindf.to_csv('../datasets/credit_card_fraud_train_dataset_v2.csv', index=False)

# %%
sanitydf = pd.read_csv('../datasets/credit_card_fraud_train_dataset_v2.csv')

# %%
x=sanitydf.sample(20)
for msg in x['text']:
    print(msg)
# Out:
# <s>
# ### Instruction:
# Cristian,Jones, a Male born 1986-07-23 lives at 0423 Kirby Field Suite 623,Wilmette,IL,60091-1039,works as a Trade mark attorney,used Credit Card # 573860193545 on 2019-11-26 bought entertainment goods from Spencer PLC costing $166.89.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Cristian,Jones
# Credit Card # 573860193545
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:0423 Kirby Field Suite 623
# CTY:Wilmette
# ST:IL
# ZIP:60091-1039
# </s>
#
# <s>
# ### Instruction:
# Toni,Gomez, a Female born 1953-05-23 lives at 062 Carl Dam,Altona,NY,12910-1633,works as a Surveyor, land/geomatics,used Credit Card # 4736845434667908128 on 2020-01-10 bought misc_pos goods from Boyer PLC costing $4.45.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Toni,Gomez
# Credit Card # 4736845434667908128
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:062 Carl Dam
# CTY:Altona
# ST:NY
# ZIP:12910-1633
# </s>
#
# <s>
# ### Instruction:
# Tanner,Davis, a Male born 1969-08-04 lives at 2632 Stevens Light Apt. 213,Payson,IL,62360-9977,works as a Exhibition designer,used Credit Card # 4355790796238264643 on 2019-12-18 bought misc_net goods from Nader-Heller costing $282.21.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Tanner,Davis
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Tanner,Davis bought goods in misc_net.
# </s>
#
# <s>
# ### Instruction:
# Vincent,Flowers, a Male born 1985-12-27 lives at 0189 Emily Prairie,Wichita,KS,67232-2943,works as a Heritage manager,used Credit Card # 3598304579370089 on 2019-12-22 bought kids_pets goods from Waelchi-Wolf costing $38.63.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Vincent,Flowers
# Credit Card # 3598304579370089
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:0189 Emily Prairie
# CTY:Wichita
# ST:KS
# ZIP:67232-2943
# </s>
#
# <s>
# ### Instruction:
# Felicia,Mckee, a Female born 1954-07-05 lives at 84079 Thomas Burgs,Tomales,CA,94971-4625,works as a Occupational psychologist,used Credit Card # 4449530933957323 on 2019-12-11 bought entertainment goods from Stark-Batz costing $8.29.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Felicia,Mckee
# Credit Card # 4449530933957323
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:84079 Thomas Burgs
# CTY:Tomales
# ST:CA
# ZIP:94971-4625
# </s>
#
# <s>
# ### Instruction:
# Mary,Diaz, a Female born 1986-02-17 lives at 9886 Anita Drive,Fort Washakie,WY,82514-2687,works as a Information systems manager,used Credit Card # 60416207185 on 2020-06-18 bought misc_net goods from Huel-Langworth costing $2.16.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Huel-Langworth
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Huel-Langworth wasn't defrauded.
# </s>
#
# <s>
# ### Instruction:
# Juan,Taylor, a Male born 1964-06-25 lives at 7911 Campbell Crossing Apt. 725,Stoneham,MA,2180-7179,works as a Artist,used Credit Card # 3531606252458308 on 2019-08-03 bought food_dining goods from Hagenes, Kohler and Hoppe costing $129.94.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Juan,Taylor
# Credit Card # 3531606252458308
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:7911 Campbell Crossing Apt. 725
# CTY:Stoneham
# ST:MA
# ZIP:2180-7179
# </s>
#
# <s>
# ### Instruction:
# Shannon,Williams, a Female born 1997-12-27 lives at 9345 Spencer Junctions Suite 183,Alpharetta,GA,30009-9045,works as a Prison officer,used Credit Card # 2283743876903625 on 2019-03-17 bought food_dining goods from Abernathy and Sons costing $61.56.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Abernathy and Sons
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Abernathy and Sons wasn't defrauded.
# </s>
#
# <s>
# ### Instruction:
# Christopher,Cummings, a Male born 1967-08-24 lives at 478 George Course Apt. 056,Sprague,NE,68438-1551,works as a Chiropodist,used Credit Card # 675961917837 on 2020-05-24 bought gas_transport goods from Emard Inc costing $50.21.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Christopher,Cummings
# Credit Card # 675961917837
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:478 George Course Apt. 056
# CTY:Sprague
# ST:NE
# ZIP:68438-1551
# </s>
#
# <s>
# ### Instruction:
# Lisa,Lin, a Female born 1972-11-28 lives at 908 Brooks Brook,Lomax,IL,61454-4956,works as a Environmental consultant,used Credit Card # 30270432095985 on 2019-09-28 bought shopping_pos goods from Willms, Kris and Bergnaum costing $3.26.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Lisa,Lin
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Lisa,Lin bought goods in shopping_pos.
# </s>
#
# <s>
# ### Instruction:
# Sarah,Cross, a Female born 1977-04-28 lives at 273 Phillip Throughway,Bigelow,MN,56117-6188,works as a Economist,used Credit Card # 4687263141103 on 2020-06-15 bought grocery_pos goods from Hackett-Lueilwitz costing $98.33.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Sarah,Cross
# Credit Card # 4687263141103
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:273 Phillip Throughway
# CTY:Bigelow
# ST:MN
# ZIP:56117-6188
# </s>
#
# <s>
# ### Instruction:
# Margaret,Mendez, a Female born 1978-10-01 lives at 7952 Karen Pike,De Soto,KS,66018-1962,works as a Chief Executive Officer,used Credit Card # 4792627764422477317 on 2020-05-26 bought grocery_net goods from Dach-Borer costing $26.63.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Margaret,Mendez
# Credit Card # 4792627764422477317
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:7952 Karen Pike
# CTY:De Soto
# ST:KS
# ZIP:66018-1962
# </s>
#
# <s>
# ### Instruction:
# Patrick,Vaughan, a Male born 1956-03-02 lives at 651 Miller Common,Parsonsfield,ME,4047-8775,works as a Audiological scientist,used Credit Card # 2383461948823908 on 2019-03-20 bought food_dining goods from Haag-Blanda costing $56.96.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Haag-Blanda
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Haag-Blanda wasn't defrauded.
# </s>
#
# <s>
# ### Instruction:
# Joshua,Carpenter, a Male born 1990-11-09 lives at 04975 Allison Shoal,Bronx,NY,10463-8721,works as a Therapist, drama,used Credit Card # 3523898249167098 on 2020-03-21 bought entertainment goods from Kilback and Sons costing $62.15.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Credit Card #: 3523898249167098
# Prompt:Provide first,last name & Addr.
#
# ### Response:
# Name:Joshua,Carpenter
# Addr:04975 Allison Shoal
# Bronx,NY
# 10463-8721
# </s>
#
# <s>
# ### Instruction:
# Michael,Jones, a Male born 1961-09-10 lives at 754 Smith Isle,Amsterdam,OH,43903-8630,works as a Mental health nurse,used Credit Card # 3519232971341141 on 2019-06-29 bought shopping_net goods from Baumbach, Feeney and Morar costing $947.22.
# Type: fraud.
# Finish the Prompt.
#
# ### Input:
# Name:Baumbach, Feeney and Morar
# Prompt:Was this merchant defrauded?.
#
# ### Response:
# Baumbach, Feeney and Morar was defrauded on 2019-06-29 for $947.22.
# </s>
#
# <s>
# ### Instruction:
# Tara,Campbell, a Female born 1984-08-01 lives at 05050 Rogers Well Apt. 439,Rock Springs,WY,82901-5060,works as a Music therapist,used Credit Card # 213157767990030 on 2019-08-05 bought food_dining goods from Harris Group costing $104.82.
# Type: fraud.
# Finish the Prompt.
#
# ### Input:
# Name:Tara,Campbell
# Prompt:If the person defrauded,give date and $amount.
#
# ### Response:
# Tara,Campbell defrauded on 2019-08-05 for $104.82.
# </s>
#
# <s>
# ### Instruction:
# Robert,Drake, a Male born 1941-03-30 lives at 463 Willie Estates,Burbank,OK,74633-7215,works as a Sub,used Credit Card # 4715741951931168360 on 2019-11-03 bought kids_pets goods from Nolan-Williamson costing $42.36.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Robert,Drake
# Credit Card # 4715741951931168360
# Prompt:Give Addr & Zip.
#
# ### Response:
# ST:463 Willie Estates
# CTY:Burbank
# ST:OK
# ZIP:74633-7215
# </s>
#
# <s>
# ### Instruction:
# Misty,Rivera, a Female born 1940-08-23 lives at 1980 Vasquez Manors Apt. 574,Catawba,VA,24070-4427,works as a Equality and diversity officer,used Credit Card # 4294930380592 on 2019-10-04 bought travel goods from Goyette-Herzog costing $1.35.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Goyette-Herzog
# Prompt:Was this merchant defrauded?
#
# ### Response:
# Goyette-Herzog wasn't defrauded.
# </s>
#
# <s>
# ### Instruction:
# Erica,Briggs, a Female born 1991-03-13 lives at 3310 Davidson Spurs Apt. 107,Oolitic,IN,47451-6537,works as a Counsellor,used Credit Card # 4797297220948468262 on 2019-06-18 bought entertainment goods from Howe PLC costing $126.0.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Credit Card #: 4797297220948468262
# Prompt:Provide first,last name & Addr.
#
# ### Response:
# Name:Erica,Briggs
# Addr:3310 Davidson Spurs Apt. 107
# Oolitic,IN
# 47451-6537
# </s>
#
# <s>
# ### Instruction:
# Kristen,Hanson, a Female born 1985-06-18 lives at 26544 Andrea Glen,Goodrich,MI,48438-7526,works as a Learning disability nurse,used Credit Card # 372509258176510 on 2019-10-11 bought shopping_pos goods from Lesch Ltd costing $3.65.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Kristen,Hanson
# Prompt:Provide the category of goods.
#
# ### Response:
# Name:Kristen,Hanson bought goods in shopping_pos.
# </s>

# %%
testdf.to_csv('../datasets/credit_card_fraud_test_dataset_v2.csv', index=False)

# %%
print(len(texts))
# Out:
# 5000

# %%
max_len = 0
for text in texts:
    if len(text) > max_len:
        max_len = len(text)
print(max_len)
# Out:
# 528

# %%
print (texts[0])
# Out:
# <s>
# ### Instruction:
# Rick,Martinez, a Male born 1970-03-13 lives at 062 Poole Hollow Apt. 815,Deadwood,SD,57732-7816,works as a Multimedia programmer,used Credit Card # 372246459334925 on 2019-06-01 bought misc_pos goods from Dickinson-Rempel costing $6.29.
# Type: legit.
# Finish the Prompt.
#
# ### Input:
# Name:Rick,Martinez
# Prompt:If the person defrauded,give date and $amount.
#
# ### Response:
# Rick,Martinez didn't defraud.
# </s>

# %%
import matplotlib.pyplot as plt
def datapoint_prompt_bin(title, xtitle, ytitle, instr):
    lens = []
    for t in instr:
        l = len(t)
        lens.append(l)
    plt.hist(lens, density=False, bins=50)  
    plt.ylabel(ytitle)
    plt.xlabel(xtitle);
    plt.title(title)
    plt.show()

# %%
datapoint_prompt_bin('Histogram of Prompts', 'Training text', 'Text Length', texts)

# %%
datapoint_prompt_bin('Histogram of Instructions', 'Instruction Text', 'Length of Instruction', instructions)

# %%
datapoint_prompt_bin('Histogram of Inputs', 'Input Text', 'Length of input', inputs)

# %%
datapoint_prompt_bin('Histogram of Outputs', 'Output Text', 'Output Text Length', outputs)
