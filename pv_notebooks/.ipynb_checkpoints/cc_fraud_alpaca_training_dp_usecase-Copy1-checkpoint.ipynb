# %%
import pandas as pd
import numpy as np
import random
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# %%
with open('../datasets/fraudTrainWithExtZip.csv') as fd:
    numcols = len(fd.readline().split(','))
df = pd.read_csv('../datasets/fraudTrainWithExtZip.csv', usecols=range(1,numcols))

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'zip_ext',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
display(df.head(5))
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city state    zip  zip_ext  \
# 0                561 Perry Cove  Moravian Falls    NC  28654     6204
# 1  43039 Riley Greens Suite 393          Orient    WA  99160     8487
# 2      594 White Dale Suite 530      Malad City    ID  83252     9323
# 3   9443 Cynthia Court Apt. 038         Boulder    MT  59632     9670
# 4              408 Bradley Rest        Doe Hill    VA  24433     3197
#
#        lat      long  city_pop                                job         dob  \
# 0  36.0788  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1  48.8878 -118.2105       149  Special educational needs teacher  1978-06-21
# 2  42.1808 -112.2620      4154        Nature conservation officer  1962-01-19
# 3  46.2306 -112.1138      1939                    Patent attorney  1967-01-12
# 4  38.4207  -79.4629        99     Dance movement psychotherapist  1986-03-28
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
num_records = 5000
scale_fraud_proportion = 20

# %%
# Reduce the number of records to above value
# We need to keep the proportion of fraud vs not fraud records the same.
fraud_prop = np.sum(df['is_fraud'] == 1)/len(df)

# Separate the fraud and not fraud records
df_fraud = df[ df['is_fraud'] == 1 ]
df_not_fraud = df[ df['is_fraud'] == 0 ]

# Get a sampling from each in the proportion and combine
fraud_count = int(num_records*fraud_prop)*scale_fraud_proportion
not_fraud_count = num_records - fraud_count

print(fraud_count, not_fraud_count)
# Sample the fraud and not fraud records
fraud_selected = df_fraud.sample(fraud_count, replace=False).reset_index(drop=True)
not_fraud_selected = df_not_fraud.sample(not_fraud_count, replace=False).reset_index(drop=True)

print(len(fraud_selected), len(not_fraud_selected))
# Combined df of both types

cdf = pd.concat([fraud_selected,not_fraud_selected])
print(len(cdf))
# Out:
# 560 4440
# 560 4440
# 5000

# %%
df_fraud = cdf[ cdf['is_fraud'] == 1 ]
df_not_fraud = cdf[ cdf['is_fraud'] == 0 ]
print(len(fraud_selected), len(not_fraud_selected))
# Out:
# 560 4440

# %%
# Shuffle the records
cdf = cdf.sample(frac=1).reset_index(drop=True)

# %%
def extract_transaction_info(rec):
    r = {}
    r['date'] = str(rec[1]['trans_date_trans_time']).split(' ')[0]
    r['cc_num'] = str(rec[1]['cc_num'])
    r['amount'] = str(rec[1]['amt'])
    r['first_name'] = str(rec[1]['first'])
    r['last_name'] = str(rec[1]['last'])
    if str(rec[1]['gender']) == 'M':
        r['gender'] = 'Male'
        r['pronoun'] = 'he'
        r['Pronoun'] = 'He'
    else:
        r['gender'] = 'Female'
        r['pronoun'] = 'she' 
        r['Pronoun'] = 'She'
    r['merchant'] = str(rec[1]['merchant'])
    if r['merchant'].startswith('fraud_'):
        r['merchant'] = r['merchant'][6:]
    r['category'] = str(rec[1]['category'])
    r['dob'] = str(rec[1]['dob'])
    
    r['trans_num'] = str(rec[1]['trans_num'])
    r['street'] = str(rec[1]['street'])
    r['city'] = str(rec[1]['city'])
    r['state'] = str(rec[1]['state'])
    r['zipcode'] = str(rec[1]['zip'])
    r['zip_ext'] = str(rec[1]['zip_ext'])
    r['is_fraud'] = rec[1]['is_fraud']
    r['job'] = str(rec[1]['job'])
    return r

# %%
basic_instruction = '''<s>
### Instruction:
A credit card transaction was made by {gender}, named {first_name}, {last_name}  
whose Birthdate is {dob} and {pronoun} lives at {street}, {city}, {state}, {zipcode}-{zip_ext}, works as a {job}.
{Pronoun} used the Credit Card Number {cc_num} on {date} to buy goods categorized as {category} from merchant {merchant}, amount ${amount}.
'''

fraud_instruction = '''This is a fradulent transaction.'''
legit_instruction = '''This is a legitimate transaction.'''

end_instruction   = '''
Complete the Prompt below using the above information and the Input information from the 
Input section. Provide your response as shown in the Response section.
'''
prompt1 = '''
### Input: 
Name: {first_name}, {last_name}
Credit Card Number: {cc_num}
Prompt: Provide the complete address, include the zip code of the Credit Card owner.
'''
response1 = '''
### Response:
Street Address: {street}
City: {city}
State: {state},
Zipcode: {zipcode}-{zip_ext}
</s>
'''

prompt2 = '''
### Input: 
Credit Card: {cc_num}
Prompt: Provide the first name, last name and the address of the Credit Card owner.
'''
response2 = '''
### Response:
Name: {first_name}, {last_name}
Address: {street}
         {city}, {state}
         {zipcode}-{zip_ext}
</s>
'''
 
prompt3 = '''
### Input: 
Name: {first_name}, {last_name}
Prompt: Provide the category of goods purchased by the above named person.
'''
response3 = '''
### Response:
Name: {first_name}, {last_name} bought goods belonging to the category {category}.
</s>
'''

prompt4 = '''
### Input: 
Name: {merchant}
Prompt: Was this merchant ever defrauded?.
'''
response4 = '''
### Response:
Merchant: {merchant} was defrauded at least once on {date} for ${amount} amount.
</s>
'''

prompt5 = '''
### Input: 
Name: {first_name}, {last_name}
Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and amount of fraud.
'''
response5 = '''
### Response:
{first_name}, {last_name} did commit Credit Card fraud on {date} for an amount of ${amount}.
</s>
'''

prompt6 = '''
### Input: 
Name: {merchant}
Prompt: Was this merchant ever defrauded?.
'''
response6 = '''
### Response:
Merchant: {merchant} was never defrauded.
</s>
'''

prompt7 = '''
### Input: 
Name: {first_name}, {last_name}
Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and amount of fraud.
'''
response7 = '''
### Response:
{first_name}, {last_name} did not ever commit Credit Card fraud.
</s>
'''

# %%
general_prompts=[prompt1, prompt2, prompt3]
general_responses = [response1, response2, response3]
fraud_prompts=[prompt4, prompt5]
fraud_responses = [response4, response5]
legit_prompts=[prompt6, prompt7]
legit_responses = [response6, response7]

# %%
def create_training_datapoints(df, instructions, inputs, outputs, texts):
    def add_new_training_datapoint(i, pi, rs):
        text = i + pi + rs
        instructions.append(i)
        inputs.append(pi)
        outputs.append(rs)
        texts.append(text)
        return
    
    for rec in df.iterrows():
        r = extract_transaction_info(rec)
        
        bi = basic_instruction.format(**r)
        ei = end_instruction.format(**r)
        
        if r['is_fraud']:
            instruction = bi + fraud_instruction + ei
        else:
            instruction = bi + legit_instruction + ei
        
        # Get a random train type for this record. We have 5 types of prompt
        # and we get a random number to train this specific record in a certain
        # prompt. 
        tt = np.random.randint(1,6)
        if tt in [1, 2, 3]:
            pi = general_prompts[tt-1].format(**r)
            rs = general_responses[tt-1].format(**r)
        elif tt in [4, 5]:
            if r['is_fraud']:
                pi = fraud_prompts[tt-4].format(**r)
                rs = fraud_responses[tt-4].format(**r)
            else:
                pi = legit_prompts[tt-4].format(**r)
                rs = legit_responses[tt-4].format(**r)
        add_new_training_datapoint(instruction, pi, rs)

# %%
inputs       = []
outputs      = []
instructions = []
texts        = []

# %%
create_training_datapoints(cdf, instructions, inputs, outputs, texts)

# %%
print(len(texts), len(cdf), len(instructions))
# Out:
# 5000 5000 5000

# %%
count=0
for text in texts:
    print(text)
    count +=1
    if count >= 20:
        break
# Out:
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Amber, Lewis
# whose Birthdate is 2004-05-08 and she lives at 6296 John Keys Suite 858, Pembroke Township, IL, 60958-3189, works as a Psychotherapist, child.
# She used the Credit Card Number 4587657402165341815 on 2019-12-25 to buy goods categorized as personal_care from merchant Gottlieb-Hansen, amount $3.86.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 4587657402165341815
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Amber, Lewis
# Address: 6296 John Keys Suite 858
#          Pembroke Township, IL
#          60958-3189
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Kimberly, Miller
# whose Birthdate is 1976-06-15 and she lives at 75533 Tamara Valleys, Logan, IL, 62856-3314, works as a Scientist, research (physical sciences).
# She used the Credit Card Number 4951647200979051 on 2019-05-07 to buy goods categorized as misc_net from merchant Brown PLC, amount $627.91.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Brown PLC
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Brown PLC was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Tina, Lawrence
# whose Birthdate is 1976-04-12 and she lives at 12444 Jacob Pines, Nobleboro, ME, 4555-7334, works as a Financial trader.
# She used the Credit Card Number 4587577161160601 on 2019-03-10 to buy goods categorized as health_fitness from merchant Dare-Gibson, amount $6.76.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 4587577161160601
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Tina, Lawrence
# Address: 12444 Jacob Pines
#          Nobleboro, ME
#          4555-7334
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Carlos, Chung
# whose Birthdate is 1972-07-25 and he lives at 8957 Russell Key, Grant, AL, 35747-9539, works as a Curator.
# He used the Credit Card Number 2266735643685262 on 2019-03-17 to buy goods categorized as grocery_net from merchant Rempel PLC, amount $19.05.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Carlos, Chung
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Carlos, Chung did not ever commit Credit Card fraud.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Sydney, Morales
# whose Birthdate is 1999-09-29 and she lives at 755 Moses Harbor, Coulee Dam, WA, 99116-2774, works as a Pilot, airline.
# She used the Credit Card Number 501851115094 on 2019-03-25 to buy goods categorized as grocery_pos from merchant Strosin-Cruickshank, amount $282.54.
# This is a fradulent transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Sydney, Morales
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and amount of fraud.
#
# ### Response:
# Sydney, Morales did commit Credit Card fraud on 2019-03-25 for an amount of $282.54.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Megan, Fernandez
# whose Birthdate is 1979-08-14 and she lives at 77127 Paul Station Apt. 495, Woods Cross, UT, 84087-6911, works as a Insurance broker.
# She used the Credit Card Number 213107169859697 on 2019-01-12 to buy goods categorized as home from merchant Windler, Goodwin and Kovacek, amount $17.68.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 213107169859697
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Megan, Fernandez
# Address: 77127 Paul Station Apt. 495
#          Woods Cross, UT
#          84087-6911
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Jeremy, Roberson
# whose Birthdate is 1993-09-29 and he lives at 25887 Martin Inlet, Graniteville, VT, 5654-7042, works as a Agricultural consultant.
# He used the Credit Card Number 4855488158131690372 on 2020-02-25 to buy goods categorized as gas_transport from merchant Emard Inc, amount $71.44.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Jeremy, Roberson
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Jeremy, Roberson did not ever commit Credit Card fraud.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Robert, Evans
# whose Birthdate is 1985-06-20 and he lives at 01892 Patricia Vista Apt. 828, Sachse, TX, 75048-4439, works as a Site engineer.
# He used the Credit Card Number 4755696071492 on 2019-08-03 to buy goods categorized as gas_transport from merchant Schaefer, McGlynn and Bosco, amount $54.89.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Robert, Evans
# Prompt: Provide the category of goods purchased by the above named person.
#
# ### Response:
# Name: Robert, Evans bought goods belonging to the category gas_transport.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Alicia, Miller
# whose Birthdate is 1979-12-27 and she lives at 976 Hubbard Lodge, Randolph, MN, 55065-4445, works as a Barrister.
# She used the Credit Card Number 4158008602445 on 2019-01-18 to buy goods categorized as kids_pets from merchant Bode-Schuster, amount $66.39.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Alicia, Miller
# Credit Card Number: 4158008602445
# Prompt: Provide the complete address, include the zip code of the Credit Card owner.
#
# ### Response:
# Street Address: 976 Hubbard Lodge
# City: Randolph
# State: MN,
# Zipcode: 55065-4445
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Carlos, Chung
# whose Birthdate is 1972-07-25 and he lives at 8957 Russell Key, Grant, AL, 35747-9539, works as a Curator.
# He used the Credit Card Number 2266735643685262 on 2019-12-04 to buy goods categorized as misc_pos from merchant Turcotte-Halvorson, amount $3.55.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Carlos, Chung
# Prompt: Provide the category of goods purchased by the above named person.
#
# ### Response:
# Name: Carlos, Chung bought goods belonging to the category misc_pos.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named James, Greene
# whose Birthdate is 1998-03-18 and he lives at 082 Hernandez Bypass Apt. 886, Quanah, TX, 79252-9933, works as a Librarian, public.
# He used the Credit Card Number 3585740823295298 on 2019-01-30 to buy goods categorized as shopping_pos from merchant Bins, Balistreri and Beatty, amount $9.72.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: James, Greene
# Prompt: Provide the category of goods purchased by the above named person.
#
# ### Response:
# Name: James, Greene bought goods belonging to the category shopping_pos.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Terrance, Mckinney
# whose Birthdate is 1966-08-08 and he lives at 42965 Christopher Fords Suite 659, Norman, AR, 71960-1276, works as a Magazine features editor.
# He used the Credit Card Number 3582754887089201 on 2019-02-03 to buy goods categorized as shopping_pos from merchant Turner and Sons, amount $586.2.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Terrance, Mckinney
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Terrance, Mckinney did not ever commit Credit Card fraud.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Vincent, Cain
# whose Birthdate is 1945-12-07 and he lives at 64851 Cole Turnpike, Hartford, AL, 36344-2490, works as a Jewellery designer.
# He used the Credit Card Number 30570197515105 on 2019-08-08 to buy goods categorized as kids_pets from merchant Hilpert-Conroy, amount $44.05.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Vincent, Cain
# Prompt: Provide the category of goods purchased by the above named person.
#
# ### Response:
# Name: Vincent, Cain bought goods belonging to the category kids_pets.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Jamie, Carr
# whose Birthdate is 1972-02-15 and she lives at 55363 Aaron Circle Suite 450, Lawn, PA, 17041-7097, works as a Special educational needs teacher.
# She used the Credit Card Number 4169759661243568 on 2019-04-06 to buy goods categorized as shopping_pos from merchant Kihn Inc, amount $1.93.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 4169759661243568
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Jamie, Carr
# Address: 55363 Aaron Circle Suite 450
#          Lawn, PA
#          17041-7097
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Olivia, Stephenson
# whose Birthdate is 1991-03-29 and she lives at 292 Cassidy Oval, Lowville, NY, 13367-2025, works as a Theme park manager.
# She used the Credit Card Number 3559679414981506 on 2019-09-11 to buy goods categorized as misc_pos from merchant Towne LLC, amount $92.41.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Towne LLC
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Towne LLC was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Lauren, Anderson
# whose Birthdate is 1972-05-04 and she lives at 11014 Chad Lake Apt. 573, Heart Butte, MT, 59448-2352, works as a Water engineer.
# She used the Credit Card Number 4716561796955522 on 2019-01-08 to buy goods categorized as home from merchant Skiles LLC, amount $39.99.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 4716561796955522
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Lauren, Anderson
# Address: 11014 Chad Lake Apt. 573
#          Heart Butte, MT
#          59448-2352
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named David, Wolfe
# whose Birthdate is 1974-12-28 and he lives at 81261 Garcia Underpass Suite 741, Southfield, MI, 48034-7941, works as a Engineer, automotive.
# He used the Credit Card Number 676369110710 on 2019-05-01 to buy goods categorized as misc_pos from merchant Roberts-Beahan, amount $5.02.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 676369110710
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: David, Wolfe
# Address: 81261 Garcia Underpass Suite 741
#          Southfield, MI
#          48034-7941
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Ashley, Whitney
# whose Birthdate is 1971-11-02 and she lives at 4038 Smith Avenue, Jones, AL, 36749-7516, works as a Materials engineer.
# She used the Credit Card Number 6011504998544485 on 2019-12-10 to buy goods categorized as shopping_pos from merchant Mohr Inc, amount $3.46.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 6011504998544485
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Ashley, Whitney
# Address: 4038 Smith Avenue
#          Jones, AL
#          36749-7516
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Keith, Sanders
# whose Birthdate is 1999-03-05 and he lives at 8030 Beck Motorway, Moorhead, MS, 38761-5149, works as a Chartered public finance accountant.
# He used the Credit Card Number 3545109339866548 on 2019-10-13 to buy goods categorized as food_dining from merchant Zboncak Ltd, amount $60.27.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Keith, Sanders
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Keith, Sanders did not ever commit Credit Card fraud.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Charles, Copeland
# whose Birthdate is 1969-09-08 and he lives at 92213 Lee Well, West Palm Beach, FL, 33404-1855, works as a Administrator, arts.
# He used the Credit Card Number 4600155880464 on 2020-03-02 to buy goods categorized as gas_transport from merchant Parisian and Sons, amount $68.08.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Parisian and Sons
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Parisian and Sons was never defrauded.
# </s>

# %%
cdf['Instructions'] = instructions
cdf['Input'] = inputs
cdf['Output'] = outputs
cdf['text'] = texts
cdf = cdf.sample(frac=1).reset_index(drop=True)
cdf
# Out:
#      trans_date_trans_time            cc_num  \
# 0      2020-06-17 03:05:46     4066595222529
# 1      2019-10-20 16:34:15   342952484382519
# 2      2019-03-18 17:38:30  6011148190095209
# 3      2019-05-25 23:17:40    38295635583927
# 4      2019-03-16 04:46:50      501899453424
# ...                    ...               ...
# 4995   2019-06-24 21:08:25     4259996134423
# 4996   2020-02-15 01:54:42  6506116513503136
# 4997   2019-01-29 14:46:41  3583635130604947
# 4998   2019-01-15 11:12:59   346208242862904
# 4999   2019-10-30 09:43:15  3579200383632826
#
#                                       merchant        category     amt  \
# 0     fraud_Rutherford, Homenick and Bergstrom     grocery_net   53.26
# 1                         fraud_Boyer-Reichert    shopping_net    7.16
# 2                         fraud_Sporer-Keebler   personal_care   61.39
# 3                         fraud_Ziemann-Waters  health_fitness   86.86
# 4                          fraud_Dickinson Ltd        misc_pos    1.14
# ...                                        ...             ...     ...
# 4995                     fraud_Breitenberg LLC          travel    9.73
# 4996                   fraud_Bartoletti-Wunsch   gas_transport   83.04
# 4997       fraud_Langosh, Wintheiser and Hyatt     food_dining   49.93
# 4998                        fraud_Predovic Inc    shopping_net  144.69
# 4999         fraud_Schoen, Kuphal and Nitzsche     grocery_pos  114.73
#
#          first       last gender                          street  \
# 0        Jamie      Olson      F   3423 Michael Canyon Suite 276
# 1        Kayla      Jones      F      6033 Young Track Suite 804
# 2        Terri     Bailey      F                  508 Erin Mount
# 3      Candice      Brown      F                9412 Harris Mews
# 4      Jessica  Dominguez      F  06393 Nancy Parkways Suite 855
# ...        ...        ...    ...                             ...
# 4995     Julie    Johnson      F   9331 Robert Passage Suite 327
# 4996  Kimberly       Rice      F      63991 Destiny Rue Apt. 651
# 4997   Crystal     Gamble      F      899 Michele View Suite 960
# 4998   Tabitha      Reyes      F           20938 Barbara Viaduct
# 4999     Tyler      Small      M                 047 Kevin Haven
#
#                city state    zip  zip_ext      lat      long  city_pop  \
# 0             River    KY  41254     4816  37.8795  -82.7251       571
# 1       East Canaan    CT   6024     5429  42.0158  -73.2913       647
# 2         Daly City    CA  94015     7877  37.6787 -122.4780    107941
# 3           O Brien    TX  79539     6591  33.3749  -99.8473       178
# 4           Gadsden    AL  35903     3851  33.9845  -85.9077     67082
# ...             ...   ...    ...      ...      ...       ...       ...
# 4995         Hudson    KS  67545     5583  38.1485  -98.6408       215
# 4996          Tyler    TX  75703     3663  32.2768  -95.3031    144160
# 4997   Philadelphia    PA  19149     2426  40.0369  -75.0664   1526206
# 4998  New York City    NY  10280     1890  40.7105  -74.0163   1577385
# 4999           Boyd    WI  54726     5153  44.9437  -91.0294      1690
#
#                              job         dob  \
# 0                 Quarry manager  1931-03-07
# 1                    Comptroller  1987-09-26
# 2              Buyer, industrial  1991-10-04
# 3                  Warden/ranger  1983-06-14
# 4              Ceramics designer  1970-01-08
# ...                          ...         ...
# 4995           Probation officer  1968-11-22
# 4996  Sports development officer  1984-05-04
# 4997         Structural engineer  1985-01-01
# 4998        Pharmacist, hospital  1961-05-13
# 4999                  IT trainer  1975-12-24
#
#                              trans_num   unix_time  merch_lat  merch_long  \
# 0     f5660782eb26482500a06d0d932363e3  1371438346  38.853671  -83.003661
# 1     6a01692155edd18dd7b40faf75febc1b  1350750855  42.227507  -73.985372
# 2     0741a351dce479138a0bf03d9073c794  1332092310  37.077696 -122.683552
# 3     63f685562049141c3a131c5afa7787c0  1337987860  33.316405  -99.537425
# 4     670d0d8d76160260fde4699d1a465cf1  1331873210  33.301826  -85.375975
# ...                                ...         ...        ...         ...
# 4995  3826836c471aadca6f2d99e755fdd111  1340572105  38.473970  -98.824984
# 4996  8b49122e1dd557cc85473ce4bf28b603  1360893282  33.238070  -96.144998
# 4997  d65783195062d894206bf6f1f6b3f1fe  1327848401  40.263500  -74.826792
# 4998  7ae705a2c16be0484d9b17e566d1bc25  1326625979  39.942183  -73.161570
# 4999  00c95aa0b3cb353b1644ccda834bd461  1351590195  45.441773  -91.295830
#
#       is_fraud                                       Instructions  \
# 0            0  <s>\n### Instruction:\nA credit card transacti...
# 1            0  <s>\n### Instruction:\nA credit card transacti...
# 2            0  <s>\n### Instruction:\nA credit card transacti...
# 3            0  <s>\n### Instruction:\nA credit card transacti...
# 4            0  <s>\n### Instruction:\nA credit card transacti...
# ...        ...                                                ...
# 4995         0  <s>\n### Instruction:\nA credit card transacti...
# 4996         0  <s>\n### Instruction:\nA credit card transacti...
# 4997         0  <s>\n### Instruction:\nA credit card transacti...
# 4998         0  <s>\n### Instruction:\nA credit card transacti...
# 4999         0  <s>\n### Instruction:\nA credit card transacti...
#
#                                                   Input  \
# 0     \n### Input: \nName: Rutherford, Homenick and ...
# 1     \n### Input: \nName: Kayla, Jones\nPrompt: Pro...
# 2     \n### Input: \nCredit Card: 6011148190095209\n...
# 3     \n### Input: \nName: Candice, Brown\nPrompt: D...
# 4     \n### Input: \nName: Jessica, Dominguez\nPromp...
# ...                                                 ...
# 4995  \n### Input: \nName: Julie, Johnson\nPrompt: D...
# 4996  \n### Input: \nName: Bartoletti-Wunsch\nPrompt...
# 4997  \n### Input: \nName: Crystal, Gamble\nCredit C...
# 4998  \n### Input: \nCredit Card: 346208242862904\nP...
# 4999  \n### Input: \nName: Schoen, Kuphal and Nitzsc...
#
#                                                  Output  \
# 0     \n### Response:\nMerchant: Rutherford, Homenic...
# 1     \n### Response:\nName: Kayla, Jones bought goo...
# 2     \n### Response:\nName: Terri, Bailey\nAddress:...
# 3     \n### Response:\nCandice, Brown did not ever c...
# 4     \n### Response:\nName: Jessica, Dominguez boug...
# ...                                                 ...
# 4995  \n### Response:\nJulie, Johnson did not ever c...
# 4996  \n### Response:\nMerchant: Bartoletti-Wunsch w...
# 4997  \n### Response:\nStreet Address: 899 Michele V...
# 4998  \n### Response:\nName: Tabitha, Reyes\nAddress...
# 4999  \n### Response:\nMerchant: Schoen, Kuphal and ...
#
#                                                    text
# 0     <s>\n### Instruction:\nA credit card transacti...
# 1     <s>\n### Instruction:\nA credit card transacti...
# 2     <s>\n### Instruction:\nA credit card transacti...
# 3     <s>\n### Instruction:\nA credit card transacti...
# 4     <s>\n### Instruction:\nA credit card transacti...
# ...                                                 ...
# 4995  <s>\n### Instruction:\nA credit card transacti...
# 4996  <s>\n### Instruction:\nA credit card transacti...
# 4997  <s>\n### Instruction:\nA credit card transacti...
# 4998  <s>\n### Instruction:\nA credit card transacti...
# 4999  <s>\n### Instruction:\nA credit card transacti...
#
# [5000 rows x 27 columns]

# %%
f"We have {len(cdf)} records, with unique credit cards={len(np.unique(cdf['cc_num']))}"
# Out:
# 'We have 5000 records, with unique credit cards=924'

# %%
# Split this into 70 30 for training and testing
mask = np.random.rand(len(cdf)) < 0.7
traindf = cdf[mask]
testdf  = cdf[~mask]

# %%
traindf.to_csv('../datasets/credit_card_fraud_train_dataset_v2.csv', index=False)

# %%
sanitydf = pd.read_csv('../datasets/credit_card_fraud_train_dataset_v2.csv')

# %%
x=sanitydf.sample(10)
for msg in x['text']:
    print(msg)
# Out:
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Stephanie, Crane
# whose Birthdate is 1955-01-05 and she lives at 144 Martinez Curve, Central, IN, 47110-6094, works as a Counsellor.
# She used the Credit Card Number 30487648872433 on 2020-02-14 to buy goods categorized as travel from merchant Tromp Group, amount $1.05.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Tromp Group
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Tromp Group was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Christina, Eaton
# whose Birthdate is 1986-11-12 and she lives at 3256 Brooks Field, Eldridge, AL, 35554-3545, works as a Politician's assistant.
# She used the Credit Card Number 4067137330196900 on 2019-11-20 to buy goods categorized as personal_care from merchant Sporer-Keebler, amount $2.24.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Christina, Eaton
# Credit Card Number: 4067137330196900
# Prompt: Provide the complete address, include the zip code of the Credit Card owner.
#
# ### Response:
# Street Address: 3256 Brooks Field
# City: Eldridge
# State: AL,
# Zipcode: 35554-3545
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Scott, Fuller
# whose Birthdate is 1984-07-20 and he lives at 861 Karen Common, Haw River, NC, 27258-9832, works as a Paramedic.
# He used the Credit Card Number 3525590521269779 on 2019-05-22 to buy goods categorized as misc_pos from merchant Halvorson Group, amount $202.26.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Halvorson Group
# Prompt: Was this merchant ever defrauded?.
#
# ### Response:
# Merchant: Halvorson Group was never defrauded.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Lawrence, Davis
# whose Birthdate is 1969-02-22 and he lives at 7421 Serrano Lane Apt. 580, Powell, TN, 37849-5784, works as a Teacher, special educational needs.
# He used the Credit Card Number 377654590313960 on 2019-03-01 to buy goods categorized as misc_pos from merchant Boehm, Predovic and Reinger, amount $157.08.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Lawrence, Davis
# Credit Card Number: 377654590313960
# Prompt: Provide the complete address, include the zip code of the Credit Card owner.
#
# ### Response:
# Street Address: 7421 Serrano Lane Apt. 580
# City: Powell
# State: TN,
# Zipcode: 37849-5784
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Audrey, Martinez
# whose Birthdate is 1953-03-19 and she lives at 343 Joshua Views, Liberty Mills, IN, 46946-5194, works as a Soil scientist.
# She used the Credit Card Number 560881134780 on 2019-11-04 to buy goods categorized as food_dining from merchant Graham, Hegmann and Hammes, amount $37.15.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Audrey, Martinez
# Credit Card Number: 560881134780
# Prompt: Provide the complete address, include the zip code of the Credit Card owner.
#
# ### Response:
# Street Address: 343 Joshua Views
# City: Liberty Mills
# State: IN,
# Zipcode: 46946-5194
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Kristen, Hanson
# whose Birthdate is 1985-06-18 and she lives at 26544 Andrea Glen, Goodrich, MI, 48438-7526, works as a Learning disability nurse.
# She used the Credit Card Number 372509258176510 on 2019-07-14 to buy goods categorized as personal_care from merchant Kozey-Kuhlman, amount $70.14.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Kristen, Hanson
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and the amount of fraud.
#
# ### Response:
# Kristen, Hanson did not ever commit Credit Card fraud.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Christopher, Henry
# whose Birthdate is 1964-03-16 and he lives at 1198 Robert Stravenue Apt. 479, Armonk, NY, 10504-1366, works as a Television/film/video producer.
# He used the Credit Card Number 675909898057 on 2019-10-19 to buy goods categorized as grocery_pos from merchant Osinski, Ledner and Leuschke, amount $323.67.
# This is a fradulent transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Christopher, Henry
# Prompt: Did the given person ever commit Credit Card Fraud? If so provide the date and amount of fraud.
#
# ### Response:
# Christopher, Henry did commit Credit Card fraud on 2019-10-19 for an amount of $323.67.
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Dustin, Roberts
# whose Birthdate is 1993-05-14 and he lives at 3283 James Station, Fayetteville, NC, 28314-4153, works as a Scientist, research (maths).
# He used the Credit Card Number 3595192916105588 on 2019-01-15 to buy goods categorized as grocery_pos from merchant Pacocha-O'Reilly, amount $297.74.
# This is a fradulent transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 3595192916105588
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Dustin, Roberts
# Address: 3283 James Station
#          Fayetteville, NC
#          28314-4153
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Male, named Curtis, Young
# whose Birthdate is 1970-10-09 and he lives at 4319 Watson Shoals Suite 658, Falconer, NY, 14733-8556, works as a Metallurgist.
# He used the Credit Card Number 30029052116970 on 2019-07-14 to buy goods categorized as kids_pets from merchant Schoen Ltd, amount $172.37.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 30029052116970
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Curtis, Young
# Address: 4319 Watson Shoals Suite 658
#          Falconer, NY
#          14733-8556
# </s>
#
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Audrey, Gonzalez
# whose Birthdate is 1929-05-06 and she lives at 34180 Lopez Plaza, Fields Landing, CA, 95537-5274, works as a Scientist, audiological.
# She used the Credit Card Number 3519607465576254 on 2019-05-30 to buy goods categorized as kids_pets from merchant Bode-Rempel, amount $25.52.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Name: Audrey, Gonzalez
# Credit Card Number: 3519607465576254
# Prompt: Provide the complete address, include the zip code of the Credit Card owner.
#
# ### Response:
# Street Address: 34180 Lopez Plaza
# City: Fields Landing
# State: CA,
# Zipcode: 95537-5274
# </s>

# %%
testdf.to_csv('../datasets/credit_card_fraud_test_dataset_v2.csv', index=False)

# %%
print(len(texts))
# Out:
# 5000

# %%
max_len = 0
for text in texts:
    if len(text) > max_len:
        max_len = len(text)
print(max_len)
# Out:
# 896

# %%
print (texts[0])
# Out:
# <s>
# ### Instruction:
# A credit card transaction was made by Female, named Amber, Lewis
# whose Birthdate is 2004-05-08 and she lives at 6296 John Keys Suite 858, Pembroke Township, IL, 60958-3189, works as a Psychotherapist, child.
# She used the Credit Card Number 4587657402165341815 on 2019-12-25 to buy goods categorized as personal_care from merchant Gottlieb-Hansen, amount $3.86.
# This is a legitimate transaction.
# Complete the Prompt below using the above information and the Input information from the
# Input section. Provide your response as shown in the Response section.
#
# ### Input:
# Credit Card: 4587657402165341815
# Prompt: Provide the first name, last name and the address of the Credit Card owner.
#
# ### Response:
# Name: Amber, Lewis
# Address: 6296 John Keys Suite 858
#          Pembroke Township, IL
#          60958-3189
# </s>
